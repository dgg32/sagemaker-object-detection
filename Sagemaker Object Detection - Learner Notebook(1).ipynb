# %% [markdown]
# # Download the Data

# %%
# !pip3 install tqdm
# !pip3 install pillow --upgrade
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (4.44.1)
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.
# Collecting pillow
#   Downloading Pillow-7.2.0-cp36-cp36m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 11.2 MB/s eta 0:00:01
# Installing collected packages: pillow
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# Successfully installed pillow-7.2.0
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.

# %%
# %matplotlib inline

import os
import tarfile
import urllib
import shutil
import json
import random
import numpy as np
import boto3
import sagemaker

from tqdm import tqdm
from sagemaker.amazon.amazon_estimator import get_image_uri
from matplotlib import pyplot as plt
from xml.etree import ElementTree as ET
from PIL import Image, ImageDraw, ImageFont

urls = ['http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz',
        'http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz']

def download_and_extract(data_dir, download_dir):
    for url in urls:
        target_file = url.split('/')[-1]
        if target_file not in os.listdir(download_dir):
            print('Downloading', url)
            urllib.request.urlretrieve(url, os.path.join(download_dir, target_file))
            tf = tarfile.open(url.split('/')[-1])
            tf.extractall(data_dir)
        else:
            print('Already downloaded', url)

if not os.path.isdir('data'):
    os.mkdir('data')

download_and_extract('data', '.')
# Out:
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz

# %% [markdown]
# # Extracting Annotations from XML Format

# %%
xml_dir = 'data/annotations/xmls/'
xml_files = [os.path.join(xml_dir, x) for x in os.listdir(xml_dir) if x[-3:] == 'xml']
xml_files[0]
# Out:
# 'data/annotations/xmls/British_Shorthair_195.xml'

# %%
classes = ['cat', 'dog']
categories = [
    {
        'class_id': 0,
        'name': 'cat'
    },
    {
        'class_id': 1,
        'name': 'dog'
    }
]

# %%
def extract_annotation(xml_file_path):
    
    tree = ET.parse(xml_file_path)
    root = tree.getroot()
    annotation = {}
    
    annotation['file'] = root.find('filename').text
    annotation['categories'] = categories
    
    size = root.find('size')
    
    annotation['image_size'] = [{
        'width': int(size.find('width').text),
        'height': int(size.find('height').text),
        'depth': int(size.find('depth').text)
    }]
    
    annotation['annotations'] = []
    
    for item in root.iter('object'):
        class_id = classes.index(item.find('name').text)
        ymin, xmin, ymax, xmax = None, None, None, None
        
        for box in item.findall('bndbox'):
            xmin = int(box.find("xmin").text)
            ymin = int(box.find("ymin").text)
            xmax = int(box.find("xmax").text)
            ymax = int(box.find("ymax").text)
        
            if all([xmin, ymin, xmax, ymax]) is not None:
                 annotation['annotations'].append({
                     'class_id': class_id,
                     'left': xmin,
                     'top': ymin,
                     'width': xmax - xmin,
                     'height': ymax - ymin
                 })
    return annotation

# %%
extract_annotation(xml_files[0])
# Out:
# {'file': 'British_Shorthair_195.jpg',
#  'categories': [{'class_id': 0, 'name': 'cat'},
#   {'class_id': 1, 'name': 'dog'}],
#  'image_size': [{'width': 500, 'height': 375, 'depth': 3}],
#  'annotations': [{'class_id': 0,
#    'left': 93,
#    'top': 89,
#    'width': 219,
#    'height': 182}]}

# %% [markdown]
# # Visualize Data

# %%
def plot_example(plt, annot, image_file_path, rows, cols, index):
    img = Image.open(image_file_path)
    draw = ImageDraw.Draw(img)
    font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 20)
    
    for a in annot['annotations']:
        box = [
            int(a['left']), int(a['top']),
            int(a['left']) + int(a['width']),
            int(a['top']) + int(a['height'])
        ]
        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(a['class_id'])], font=font)
    plt.subplot(rows, cols, index + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    return plt

def show_random_annotations(plt):
    plt.figure(figsize=(16, 16))
    for i in range(0, 9):
        index = random.randint(0, len(xml_files) - 1)
        
        annot = extract_annotation(xml_files[index])
        image_file_path = os.path.join('data/images/', annot['file'])

        plt = plot_example(plt, annot, image_file_path, 3, 3, i)
    plt.show()

# %%
show_random_annotations(plt)

# %% [markdown]
# # SageMaker Setup

# %%
role = sagemaker.get_execution_role()
bucket_name = "dgg32-petsdata"

training_image = get_image_uri(boto3.Session().region_name, "object-detection", repo_version="latest")

print (training_image)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/object-detection:latest

# %%
folders = ['train', 'train_annotation', 'validation', 'validation_annotation']

for folder in folders:
    if os.path.isdir(folder):
        shutil.rmtree(folder)
    os.mkdir(folder)

# %% [markdown]
# # Preparing Data for SageMaker

# %%
print('Total examples:', len(xml_files))
# Out:
# Total examples: 3686

# %%
for xml_file in tqdm(xml_files):
    target_set = 'train' if random.randint(0, 99) < 75 else 'validation'
    annot = extract_annotation(xml_file)
    image_file_path = os.path.join('data/images/', annot['file'])
    image_target_path = os.path.join(target_set, annot['file'])
    shutil.copy(image_file_path, image_target_path)
    json_file_path = os.path.join(target_set + '_annotation', annot['file'][:-3] + 'json')
    with open(json_file_path, 'w') as f:
        json.dump(annot, f)
# Out:
# 100%|██████████| 3686/3686 [00:01<00:00, 2284.66it/s]

# %%
train_images = os.listdir('train')
train_annots = os.listdir('train_annotation')

# %%
print(len(train_annots), len(train_images))
# Out:
# 2768 2768

# %%
for image in train_images:
    key = image.split('.')[0]
    json_file = key + '.json'
    if json_file not in train_annots:
        print('Not found', json_file)

# %% [markdown]
# # Uploading Data to S3

# %%
sess = sagemaker.Session()

print ("Uploading data..")
s3_train_path = sess.upload_data(path="train", bucket = bucket_name, key_prefix="train")
s3_train_annotation = sess.upload_data(path="train_annotation", bucket=bucket_name, key_prefix="train_annotation")

s3_validation_path = sess.upload_data(path="validation", bucket = bucket_name, key_prefix="validation")
s3_validation_annotation = sess.upload_data(path="validation_annotation", bucket=bucket_name, key_prefix="validation_annotation")
# Out:
# Uploading data..

# %%
s3_validation_annotation
# Out:
# 's3://dgg32-petsdata/validation_annotation'

# %% [markdown]
# # SageMaker Estimator

# %%
model = sagemaker.estimator.Estimator(
    training_image,
    role = role,
    train_instance_type = "ml.p3.2xlarge",
    train_instance_count = 1,
    train_volume_size = 100,
    train_max_run = 36000,
    input_mode = "File",
    output_path = "s3://dgg32-petsdata/output",
    sagemaker_session = sess
)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# # Hyperparameters

# %%
model.set_hyperparameters (
    base_network="resnet-50",
    num_classes = 2,
    use_pretrained_model = 1,
    mini_batch_size = 16,
    epochs = 15,
    learning_rate = 0.001,
    optimizer = "sgd",
    lr_scheduler_step = "10",
    lr_scheduler_factor = 0.1,
    momentum = 0.9,
    weight_decay = 0.0005,
    overlap_threshold = 0.5,
    nms_threshold = 0.45,
    image_shape= 512,
    num_training_samples = len(train_annots)
)

# %% [markdown]
# # Data Channels

# %%
from sagemaker.session import s3_input

train_data = s3_input(s3_train_path, distribution="FullyReplicated", content_type="application/x-image", s3_data_type="S3Prefix")
validation_data = s3_input(s3_validation_path, distribution="FullyReplicated", content_type="application/x-image", s3_data_type="S3Prefix")
train_annotation_data = s3_input(s3_train_annotation, distribution="FullyReplicated", content_type="application/x-image", s3_data_type="S3Prefix")
validation_annotation_data = s3_input(s3_validation_annotation, distribution="FullyReplicated", content_type="application/x-image", s3_data_type="S3Prefix")
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
data_channels = {
    "train": train_data,
    "validation": validation_data,
    "train_annotation": train_annotation_data,
    "validation_annotation": validation_annotation_data
}

# %%
data_channels
# Out:
# {'train': <sagemaker.inputs.s3_input at 0x7f407c234a90>,
#  'validation': <sagemaker.inputs.s3_input at 0x7f407c234d68>,
#  'train_annotation': <sagemaker.inputs.s3_input at 0x7f407c234860>,
#  'validation_annotation': <sagemaker.inputs.s3_input at 0x7f407c2348d0>}

# %% [markdown]
# # Model Training

# %%
model.fit(inputs=data_channels, logs= True)
# Out:
# 2020-09-12 19:57:11 Starting - Starting the training job...
# 2020-09-12 19:57:13 Starting - Launching requested ML instances......
# 2020-09-12 19:58:25 Starting - Preparing the instances for training......
# 2020-09-12 19:59:41 Downloading - Downloading input data.........
# 2020-09-12 20:01:13 Training - Downloading the training image...
# 2020-09-12 20:01:34 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# [09/12/2020 20:01:38 INFO 139628298073920] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [09/12/2020 20:01:38 INFO 139628298073920] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'15', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'lr_scheduler_step': u'10', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'2768', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'2', u'lr_scheduler_factor': u'0.1'}
# [09/12/2020 20:01:38 INFO 139628298073920] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'15', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'10', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'2768', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'2', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [09/12/2020 20:01:38 INFO 139628298073920] Using default worker.
# [09/12/2020 20:01:39 INFO 139628298073920] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [09/12/2020 20:01:39 INFO 139628298073920] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [09/12/2020 20:01:39 INFO 139628298073920] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [09/12/2020 20:01:39 INFO 139628298073920] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [09/12/2020 20:01:39 INFO 139628298073920] Checkpoint loading and saving are disabled.
# [09/12/2020 20:01:40 INFO 139628298073920] nvidia-smi took: 0.0755150318146 secs to identify 1 gpus
# Creating .rec file from /opt/ml/input/data/train/train.lst in /opt/ml/input/data/train
# time: 0.0648639202118  count: 0
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# time: 1.11950707436  count: 1000
# Corrupt JPEG data: premature end of data segment
# time: 1.11847281456  count: 2000
# Creating .rec file from /opt/ml/input/data/validation/val.lst in /opt/ml/input/data/validation
# time: 0.0119519233704  count: 0
# [09/12/2020 20:01:46 INFO 139628298073920] Number of GPUs being used: 1
# [09/12/2020 20:01:46 WARNING 139628298073920] Training images are resized to image shape (3, 512, 512)
# [20:01:46] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, use 7 threads for decoding..
# [20:01:46] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/train.rec, label padding width: 350
# [09/12/2020 20:01:48 WARNING 139628298073920] Validation images are resized to image shape (3, 512, 512)
# [20:01:48] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, use 7 threads for decoding..
# [20:01:49] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/val.rec, label padding width: 350
# [09/12/2020 20:01:51 INFO 139628298073920] Number of GPUs being used: 1
# [09/12/2020 20:01:51 INFO 139628298073920] Using [gpu(0)] as training context.
# [09/12/2020 20:01:51 INFO 139628298073920] Number of GPUs being used: 1
# [09/12/2020 20:01:51 INFO 139628298073920] Create Store: device
# [09/12/2020 20:01:51 INFO 139628298073920] Using (gpu(0)) as training context.
# [09/12/2020 20:01:51 INFO 139628298073920] Start training from pretrained model 1.
# [20:01:51] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [20:01:51] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [09/12/2020 20:01:52 INFO 139628298073920] Loaded pretrained model parameters.
# [09/12/2020 20:02:06 INFO 139628298073920] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1599940926.826658, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1599940926.826558}
#
# [20:02:06] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [09/12/2020 20:02:43 INFO 139628298073920] Epoch:    0, batches:    100, num_examples:   1600, 43.2 samples/sec, epoch time so far:  0:00:37.032692
# [09/12/2020 20:03:05 INFO 139628298073920] #quality_metric: host=algo-1, epoch=0, batch=173 train cross_entropy <loss>=(1.1037347415770202)
# [09/12/2020 20:03:05 INFO 139628298073920] #quality_metric: host=algo-1, epoch=0, batch=173 train smooth_l1 <loss>=(0.6424822395230517)
# [09/12/2020 20:03:05 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:03:05 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:03:17 INFO 139628298073920] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(0.149021269880468)
# [09/12/2020 20:03:17 INFO 139628298073920] Updating the best model with validation-mAP=0.149021269880468
# [09/12/2020 20:03:18 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:03:18 INFO 139628298073920] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1599940998.018983, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1599940926.826983}
#
# [09/12/2020 20:03:51 INFO 139628298073920] Epoch:    1, batches:    100, num_examples:   1600, 47.1 samples/sec, epoch time so far:  0:00:33.975616
# [09/12/2020 20:04:13 INFO 139628298073920] #quality_metric: host=algo-1, epoch=1, batch=173 train cross_entropy <loss>=(0.8594069616614507)
# [09/12/2020 20:04:13 INFO 139628298073920] #quality_metric: host=algo-1, epoch=1, batch=173 train smooth_l1 <loss>=(0.5795109660695236)
# [09/12/2020 20:04:13 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:04:13 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:04:23 INFO 139628298073920] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.3693322993940586)
# [09/12/2020 20:04:23 INFO 139628298073920] Updating the best model with validation-mAP=0.3693322993940586
# [09/12/2020 20:04:24 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:04:24 INFO 139628298073920] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1599941064.046289, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1599940998.019152}
#
# [09/12/2020 20:04:57 INFO 139628298073920] Epoch:    2, batches:    100, num_examples:   1600, 47.5 samples/sec, epoch time so far:  0:00:33.675547
# [09/12/2020 20:05:19 INFO 139628298073920] #quality_metric: host=algo-1, epoch=2, batch=173 train cross_entropy <loss>=(0.730193457559974)
# [09/12/2020 20:05:19 INFO 139628298073920] #quality_metric: host=algo-1, epoch=2, batch=173 train smooth_l1 <loss>=(0.5317755908830791)
# [09/12/2020 20:05:19 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:05:19 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:05:29 INFO 139628298073920] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.692842522881493)
# [09/12/2020 20:05:29 INFO 139628298073920] Updating the best model with validation-mAP=0.692842522881493
# [09/12/2020 20:05:29 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:05:29 INFO 139628298073920] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1599941129.893135, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1599941064.046557}
#
# [09/12/2020 20:06:03 INFO 139628298073920] Epoch:    3, batches:    100, num_examples:   1600, 47.2 samples/sec, epoch time so far:  0:00:33.888053
# [09/12/2020 20:06:25 INFO 139628298073920] #quality_metric: host=algo-1, epoch=3, batch=173 train cross_entropy <loss>=(0.6430828220890905)
# [09/12/2020 20:06:25 INFO 139628298073920] #quality_metric: host=algo-1, epoch=3, batch=173 train smooth_l1 <loss>=(0.4481630411156224)
# [09/12/2020 20:06:25 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:06:25 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:06:36 INFO 139628298073920] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.8257417239627093)
# [09/12/2020 20:06:36 INFO 139628298073920] Updating the best model with validation-mAP=0.8257417239627093
# [09/12/2020 20:06:36 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:06:36 INFO 139628298073920] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1599941196.588908, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1599941129.893329}
#
# [09/12/2020 20:07:10 INFO 139628298073920] Epoch:    4, batches:    100, num_examples:   1600, 46.9 samples/sec, epoch time so far:  0:00:34.092602
# [09/12/2020 20:07:32 INFO 139628298073920] #quality_metric: host=algo-1, epoch=4, batch=173 train cross_entropy <loss>=(0.5936644581066246)
# [09/12/2020 20:07:32 INFO 139628298073920] #quality_metric: host=algo-1, epoch=4, batch=173 train smooth_l1 <loss>=(0.370226579717124)
# [09/12/2020 20:07:32 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:07:32 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:07:43 INFO 139628298073920] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.925924067919365)
# [09/12/2020 20:07:43 INFO 139628298073920] Updating the best model with validation-mAP=0.925924067919365
# [09/12/2020 20:07:43 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:07:43 INFO 139628298073920] #progress_metric: host=algo-1, completed 33 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1599941263.740876, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1599941196.589163}
#
# [09/12/2020 20:08:17 INFO 139628298073920] Epoch:    5, batches:    100, num_examples:   1600, 47.7 samples/sec, epoch time so far:  0:00:33.519104
# [09/12/2020 20:08:38 INFO 139628298073920] #quality_metric: host=algo-1, epoch=5, batch=173 train cross_entropy <loss>=(0.5608504464910611)
# [09/12/2020 20:08:38 INFO 139628298073920] #quality_metric: host=algo-1, epoch=5, batch=173 train smooth_l1 <loss>=(0.3202206396506401)
# [09/12/2020 20:08:38 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:08:39 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:08:50 INFO 139628298073920] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.951590483817822)
# [09/12/2020 20:08:50 INFO 139628298073920] Updating the best model with validation-mAP=0.951590483817822
# [09/12/2020 20:08:50 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:08:50 INFO 139628298073920] #progress_metric: host=algo-1, completed 40 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1599941330.742571, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1599941263.741084}
#
# [09/12/2020 20:09:24 INFO 139628298073920] Epoch:    6, batches:    100, num_examples:   1600, 47.7 samples/sec, epoch time so far:  0:00:33.517627
# [09/12/2020 20:09:45 INFO 139628298073920] #quality_metric: host=algo-1, epoch=6, batch=173 train cross_entropy <loss>=(0.5339577462992465)
# [09/12/2020 20:09:45 INFO 139628298073920] #quality_metric: host=algo-1, epoch=6, batch=173 train smooth_l1 <loss>=(0.290000888908625)
# [09/12/2020 20:09:45 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:09:45 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:09:57 INFO 139628298073920] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.9787004455743296)
# [09/12/2020 20:09:57 INFO 139628298073920] Updating the best model with validation-mAP=0.9787004455743296
# [09/12/2020 20:09:57 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:09:57 INFO 139628298073920] #progress_metric: host=algo-1, completed 46 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1599941397.643215, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1599941330.742783}
#
# [09/12/2020 20:10:31 INFO 139628298073920] Epoch:    7, batches:    100, num_examples:   1600, 47.6 samples/sec, epoch time so far:  0:00:33.586796
# [09/12/2020 20:10:52 INFO 139628298073920] #quality_metric: host=algo-1, epoch=7, batch=173 train cross_entropy <loss>=(0.5056168656789654)
# [09/12/2020 20:10:52 INFO 139628298073920] #quality_metric: host=algo-1, epoch=7, batch=173 train smooth_l1 <loss>=(0.25396131126159927)
# [09/12/2020 20:10:52 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:10:52 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:11:03 INFO 139628298073920] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.9863279691929552)
# [09/12/2020 20:11:03 INFO 139628298073920] Updating the best model with validation-mAP=0.9863279691929552
# [09/12/2020 20:11:03 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:11:03 INFO 139628298073920] #progress_metric: host=algo-1, completed 53 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1599941463.879919, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1599941397.643406}
#
# [09/12/2020 20:11:37 INFO 139628298073920] Epoch:    8, batches:    100, num_examples:   1600, 47.4 samples/sec, epoch time so far:  0:00:33.734759
# [09/12/2020 20:11:59 INFO 139628298073920] #quality_metric: host=algo-1, epoch=8, batch=173 train cross_entropy <loss>=(0.4862264577331835)
# [09/12/2020 20:11:59 INFO 139628298073920] #quality_metric: host=algo-1, epoch=8, batch=173 train smooth_l1 <loss>=(0.2361995065211649)
# [09/12/2020 20:11:59 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:11:59 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:12:11 INFO 139628298073920] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.989002437211203)
# [09/12/2020 20:12:11 INFO 139628298073920] Updating the best model with validation-mAP=0.989002437211203
# [09/12/2020 20:12:12 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:12:12 INFO 139628298073920] #progress_metric: host=algo-1, completed 60 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1599941532.08864, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1599941463.880134}
#
# [09/12/2020 20:12:45 INFO 139628298073920] Epoch:    9, batches:    100, num_examples:   1600, 48.1 samples/sec, epoch time so far:  0:00:33.295855
# [09/12/2020 20:13:06 INFO 139628298073920] #quality_metric: host=algo-1, epoch=9, batch=173 train cross_entropy <loss>=(0.46572124007355464)
# [09/12/2020 20:13:06 INFO 139628298073920] #quality_metric: host=algo-1, epoch=9, batch=173 train smooth_l1 <loss>=(0.2208353784960815)
# [09/12/2020 20:13:06 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:13:07 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:13:18 INFO 139628298073920] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.9905413666112942)
# [09/12/2020 20:13:18 INFO 139628298073920] Updating the best model with validation-mAP=0.9905413666112942
# [09/12/2020 20:13:18 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:13:18 INFO 139628298073920] #progress_metric: host=algo-1, completed 66 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1599941598.917577, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1599941532.089505}
#
# [09/12/2020 20:13:52 INFO 139628298073920] Epoch:    10, batches:    100, num_examples:   1600, 47.5 samples/sec, epoch time so far:  0:00:33.652589
# [09/12/2020 20:14:14 INFO 139628298073920] #quality_metric: host=algo-1, epoch=10, batch=173 train cross_entropy <loss>=(0.45001084102610805)
# [09/12/2020 20:14:14 INFO 139628298073920] #quality_metric: host=algo-1, epoch=10, batch=173 train smooth_l1 <loss>=(0.19918510688208946)
# [09/12/2020 20:14:14 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:14:14 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:14:25 INFO 139628298073920] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.9923815330957821)
# [09/12/2020 20:14:25 INFO 139628298073920] Updating the best model with validation-mAP=0.9923815330957821
# [09/12/2020 20:14:25 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:14:25 INFO 139628298073920] #progress_metric: host=algo-1, completed 73 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1599941665.987222, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1599941598.91778}
#
# [09/12/2020 20:14:59 INFO 139628298073920] Epoch:    11, batches:    100, num_examples:   1600, 48.0 samples/sec, epoch time so far:  0:00:33.321752
# [09/12/2020 20:15:20 INFO 139628298073920] #quality_metric: host=algo-1, epoch=11, batch=173 train cross_entropy <loss>=(0.4467448367784192)
# [09/12/2020 20:15:20 INFO 139628298073920] #quality_metric: host=algo-1, epoch=11, batch=173 train smooth_l1 <loss>=(0.19849271736559113)
# [09/12/2020 20:15:20 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:15:20 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:15:31 INFO 139628298073920] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.9903207478250389)
# [09/12/2020 20:15:31 INFO 139628298073920] #progress_metric: host=algo-1, completed 80 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1599941731.487244, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1599941665.987424}
#
# [09/12/2020 20:16:05 INFO 139628298073920] Epoch:    12, batches:    100, num_examples:   1600, 47.4 samples/sec, epoch time so far:  0:00:33.727097
# [09/12/2020 20:16:26 INFO 139628298073920] #quality_metric: host=algo-1, epoch=12, batch=173 train cross_entropy <loss>=(0.43626641320256193)
# [09/12/2020 20:16:26 INFO 139628298073920] #quality_metric: host=algo-1, epoch=12, batch=173 train smooth_l1 <loss>=(0.18913646554805716)
# [09/12/2020 20:16:26 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:16:26 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:16:37 INFO 139628298073920] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.9930573802810634)
# [09/12/2020 20:16:37 INFO 139628298073920] Updating the best model with validation-mAP=0.9930573802810634
# [09/12/2020 20:16:37 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:16:37 INFO 139628298073920] #progress_metric: host=algo-1, completed 86 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1599941797.797385, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1599941731.487414}
#
# [09/12/2020 20:17:10 INFO 139628298073920] Epoch:    13, batches:    100, num_examples:   1600, 48.4 samples/sec, epoch time so far:  0:00:33.044228
# [09/12/2020 20:17:32 INFO 139628298073920] #quality_metric: host=algo-1, epoch=13, batch=173 train cross_entropy <loss>=(0.4248446623484294)
# [09/12/2020 20:17:32 INFO 139628298073920] #quality_metric: host=algo-1, epoch=13, batch=173 train smooth_l1 <loss>=(0.17867711422010077)
# [09/12/2020 20:17:32 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:17:32 INFO 139628298073920] Updated the metrics
# [09/12/2020 20:17:43 INFO 139628298073920] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.9935618130956332)
# [09/12/2020 20:17:43 INFO 139628298073920] Updating the best model with validation-mAP=0.9935618130956332
# [09/12/2020 20:17:43 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:17:44 INFO 139628298073920] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1599941864.008985, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1599941797.797662}
#
# [09/12/2020 20:18:17 INFO 139628298073920] Epoch:    14, batches:    100, num_examples:   1600, 48.0 samples/sec, epoch time so far:  0:00:33.355986
# [09/12/2020 20:18:38 INFO 139628298073920] #quality_metric: host=algo-1, epoch=14, batch=173 train cross_entropy <loss>=(0.41068740314886043)
# [09/12/2020 20:18:38 INFO 139628298073920] #quality_metric: host=algo-1, epoch=14, batch=173 train smooth_l1 <loss>=(0.16995379364328797)
# [09/12/2020 20:18:38 INFO 139628298073920] Round of batches complete
# [09/12/2020 20:18:38 INFO 139628298073920] Updated the metrics
#
# 2020-09-12 20:18:53 Uploading - Uploading generated training model[09/12/2020 20:18:49 INFO 139628298073920] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.993322933932139)
# [09/12/2020 20:18:49 INFO 139628298073920] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1599941929.024352, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1599941864.009269}
#
# [09/12/2020 20:18:49 WARNING 139628298073920] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/12/2020 20:18:49 INFO 139628298073920] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [09/12/2020 20:18:49 INFO 139628298073920] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "totaltime": {"count": 1, "max": 1031796.4119911194, "sum": 1031796.4119911194, "min": 1031796.4119911194}, "setuptime": {"count": 1, "max": 10.492086410522461, "sum": 10.492086410522461, "min": 10.492086410522461}}, "EndTime": 1599941930.748628, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1599940899.427773}
#
#
# 2020-09-12 20:19:15 Completed - Training job completed
# Training seconds: 1174
# Billable seconds: 1174

# %% [markdown]
# # Deploy Model

# %%
deployed_model = model.deploy(initial_instance_count=1, instance_type="ml.m4.xlarge")
print ("\nModel deployed")
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!
# Model deployed

# %% [markdown]
# # Predictions

# %%
image_dir = 'validation'
images = [x for x in os.listdir(image_dir) if x[-3:] == 'jpg']
print(len(images))
# Out:
# 918

# %%
deployed_model.content_type = "image/jpeg"

# %%
index = 0

image_path = os.path.join(image_dir, images[index])
#image_path = 'dog_cat.jfif'

with open(image_path, 'rb') as f:
    b = bytearray(f.read())

results = deployed_model.predict(b)
results = json.loads(results)

preds = results['prediction']

# %%
preds[0]
# Out:
# [1.0,
#  0.8699483275413513,
#  0.3114490509033203,
#  0.3012043833732605,
#  0.4404257535934448,
#  0.4321139454841614]

# %%
img = Image.open(image_path)
draw = ImageDraw.Draw(img)
font = ImageFont.truetype('/usr/share/fonts/dejavu/DejaVuSerif-Bold.ttf', 30)
w, h =img.size

for pred in preds:
    class_id, score, xmin, ymin, xmax, ymax = pred
    
    if score > 0.7:
        box = [w*xmin, h*ymin, w*xmax, h*ymax]

        draw.rectangle(box, outline='yellow', width=4)
        draw.text((box[0], box[1]), classes[int(class_id)], font=font, fill='#000000')
    else:
        break

plt.xticks([])
plt.yticks([])
plt.imshow(img)
plt.show()

# %% [markdown]
# Don't forget!! You need to delete endpoint or else you will continue to accrue cost!

# %%
sagemaker.Session().delete_endpoint(deployed_model.endpoint)
